# %%
import matplotlib.pyplot as plt
import yfinance as yf
import pandas as pd
import numpy as np

# %%
# download data in monthly intervals (otherwise recursive tests are too slow on such a long period)
sp500 = yf.Ticker("^GSPC").history(start="1990-01-01", end="2025-12-31", interval="1mo")

# %%
# LaTex
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'

# Borderstyle
border_color = ax.spines['left'].get_edgecolor()
border_width = ax.spines['left'].get_linewidth()

plt.plot(sp500.index, sp500["Close"], color='black', linewidth=0.8, label='S\&P 500')
plt.ylabel(r'$P_t$')
plt.tight_layout()
plt.grid(True, alpha=0.5, linestyle='--')
plt.legend()
plt.xlim(pd.Timestamp('1990-01-01'), pd.Timestamp('2025-12-31'))
plt.show()
